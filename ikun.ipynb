# %%
import torch
import torch.nn as nn
from torchvision import transforms, datasets
from torch.utils.data import Dataset, DataLoader
import os
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

data_transforms = transforms.Compose([
    transforms.RandomRotation(20),
    transforms.RandomAffine(degrees=0, translate=(0.2, 0.2)),
    transforms.RandomResizedCrop(size=224, scale=(0.8, 1.2)),
    transforms.RandomHorizontalFlip(p=1.0),
    transforms.ColorJitter(brightness=(0.8, 1.2)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])
base_dir = 'ikun/train'
dataset = datasets.ImageFolder(base_dir, transform=data_transforms)
dataloader = DataLoader(dataset, batch_size=8, shuffle=True)


class WXZ(nn.Module):
    def __init__(self, num_classes=2):
        super(WXZ, self).__init__()
        self.conv_layers = nn.Sequential(
            nn.Conv2d(3, 32, 3, 1, padding='same'),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, 1, padding='same'),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 128, 3, 1, padding='same'),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.fc_layers = nn.Sequential(
            nn.Flatten(),
            nn.ReLU(),
            nn.Linear(128 * 28 * 28, 1024),
            nn.ReLU(),
            nn.LayerNorm(1024),
            nn.Linear(1024, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = self.fc_layers(x)
        return x


model = WXZ().to(device)
loss_ikun = nn.CrossEntropyLoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)
writer = SummaryWriter('ikun_CNN')
num_epochs = 50
model.train()
for epoch in range(num_epochs):
    running_loss = 0.0
    correct = 0
    total = 0
    for inputs, labels in dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_ikun(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        print(f'Epoch {epoch + 1}/{num_epochs}训练完成,loss:{running_loss / len(dataloader):.4f}, Acc: {100*correct/total:.2f}%')
    avg_loss = running_loss / len(dataloader)
    train_acc = 100 * correct / total
    writer.add_scalar('Train Loss', avg_loss, epoch)
    writer.add_scalar('Train Acc', train_acc, epoch)
    writer.add_images('train_imgs', inputs.cpu(), 10)
    writer.close()
test_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])
test_dir = 'ikun/val'
test_dataset = datasets.ImageFolder(test_dir, transform=test_transform)
test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False)
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in test_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
test_acc = 100 * correct / total
print(f'测试精准度:{test_acc:.2f}%')
writer.add_scalar('Test acc', test_acc, num_epochs)
writer.add_graph(model, torch.rand(1, 3, 224, 224).to(device))
writer.close()
torch.save(model.state_dict(), 'ikun_ball_model.pth')
writer.close()
# Out:
# Using device: cuda
# Epoch 1/50训练完成,loss:0.0815, Acc: 50.00%
# Epoch 1/50训练完成,loss:0.1464, Acc: 56.25%
# Epoch 1/50训练完成,loss:0.2036, Acc: 58.33%
# Epoch 1/50训练完成,loss:0.3040, Acc: 56.25%
# Epoch 1/50训练完成,loss:0.3773, Acc: 55.00%
# Epoch 1/50训练完成,loss:0.4592, Acc: 54.17%
# Epoch 1/50训练完成,loss:0.5493, Acc: 53.57%
# Epoch 1/50训练完成,loss:0.6516, Acc: 53.12%
# Epoch 1/50训练完成,loss:0.7082, Acc: 55.56%
# Epoch 1/50训练完成,loss:0.8301, Acc: 52.50%
# Epoch 2/50训练完成,loss:0.0767, Acc: 62.50%
# Epoch 2/50训练完成,loss:0.1347, Acc: 56.25%
# Epoch 2/50训练完成,loss:0.1898, Acc: 58.33%
# Epoch 2/50训练完成,loss:0.2428, Acc: 62.50%
# Epoch 2/50训练完成,loss:0.3092, Acc: 67.50%
# Epoch 2/50训练完成,loss:0.3851, Acc: 64.58%
# Epoch 2/50训练完成,loss:0.4453, Acc: 64.29%
# Epoch 2/50训练完成,loss:0.4935, Acc: 65.62%
# Epoch 2/50训练完成,loss:0.5725, Acc: 65.28%
# Epoch 2/50训练完成,loss:0.6015, Acc: 67.50%
# Epoch 3/50训练完成,loss:0.0527, Acc: 87.50%
# Epoch 3/50训练完成,loss:0.0766, Acc: 87.50%
# Epoch 3/50训练完成,loss:0.0967, Acc: 87.50%
# Epoch 3/50训练完成,loss:0.1420, Acc: 84.38%
# Epoch 3/50训练完成,loss:0.1883, Acc: 82.50%
# Epoch 3/50训练完成,loss:0.2206, Acc: 83.33%
# Epoch 3/50训练完成,loss:0.2538, Acc: 83.93%
# Epoch 3/50训练完成,loss:0.2983, Acc: 82.81%
# Epoch 3/50训练完成,loss:0.3582, Acc: 81.94%
# Epoch 3/50训练完成,loss:0.3622, Acc: 83.75%
# Epoch 4/50训练完成,loss:0.0075, Acc: 100.00%
# Epoch 4/50训练完成,loss:0.0833, Acc: 75.00%
# Epoch 4/50训练完成,loss:0.0937, Acc: 83.33%
# Epoch 4/50训练完成,loss:0.1125, Acc: 84.38%
# Epoch 4/50训练完成,loss:0.1535, Acc: 82.50%
# Epoch 4/50训练完成,loss:0.1562, Acc: 85.42%
# Epoch 4/50训练完成,loss:0.1614, Acc: 87.50%
# Epoch 4/50训练完成,loss:0.1869, Acc: 87.50%
# Epoch 4/50训练完成,loss:0.2034, Acc: 87.50%
# Epoch 4/50训练完成,loss:0.2818, Acc: 86.25%
# Epoch 5/50训练完成,loss:0.0066, Acc: 100.00%
# Epoch 5/50训练完成,loss:0.0173, Acc: 100.00%
# Epoch 5/50训练完成,loss:0.0188, Acc: 100.00%
# Epoch 5/50训练完成,loss:0.0421, Acc: 100.00%
# Epoch 5/50训练完成,loss:0.0524, Acc: 100.00%
# Epoch 5/50训练完成,loss:0.1052, Acc: 97.92%
# Epoch 5/50训练完成,loss:0.1331, Acc: 96.43%
# Epoch 5/50训练完成,loss:0.1364, Acc: 96.88%
# Epoch 5/50训练完成,loss:0.2426, Acc: 93.06%
# Epoch 5/50训练完成,loss:0.2923, Acc: 92.50%
# Epoch 6/50训练完成,loss:0.0391, Acc: 75.00%
# Epoch 6/50训练完成,loss:0.0633, Acc: 81.25%
# Epoch 6/50训练完成,loss:0.0971, Acc: 79.17%
# Epoch 6/50训练完成,loss:0.1062, Acc: 84.38%
# Epoch 6/50训练完成,loss:0.1860, Acc: 80.00%
# Epoch 6/50训练完成,loss:0.2107, Acc: 81.25%
# Epoch 6/50训练完成,loss:0.2163, Acc: 83.93%
# Epoch 6/50训练完成,loss:0.2201, Acc: 85.94%
# Epoch 6/50训练完成,loss:0.2514, Acc: 84.72%
# Epoch 6/50训练完成,loss:0.2794, Acc: 85.00%
# Epoch 7/50训练完成,loss:0.0043, Acc: 100.00%
# Epoch 7/50训练完成,loss:0.0144, Acc: 100.00%
# Epoch 7/50训练完成,loss:0.0471, Acc: 91.67%
# Epoch 7/50训练完成,loss:0.1021, Acc: 90.62%
# Epoch 7/50训练完成,loss:0.1060, Acc: 92.50%
# Epoch 7/50训练完成,loss:0.1349, Acc: 89.58%
# Epoch 7/50训练完成,loss:0.1427, Acc: 91.07%
# Epoch 7/50训练完成,loss:0.2020, Acc: 89.06%
# Epoch 7/50训练完成,loss:0.2085, Acc: 90.28%
# Epoch 7/50训练完成,loss:0.2508, Acc: 90.00%
# Epoch 8/50训练完成,loss:0.0567, Acc: 87.50%
# Epoch 8/50训练完成,loss:0.0632, Acc: 93.75%
# Epoch 8/50训练完成,loss:0.0795, Acc: 91.67%
# Epoch 8/50训练完成,loss:0.0798, Acc: 93.75%
# Epoch 8/50训练完成,loss:0.0814, Acc: 95.00%
# Epoch 8/50训练完成,loss:0.1311, Acc: 91.67%
# Epoch 8/50训练完成,loss:0.1457, Acc: 92.86%
# Epoch 8/50训练完成,loss:0.1461, Acc: 93.75%
# Epoch 8/50训练完成,loss:0.1480, Acc: 94.44%
# Epoch 8/50训练完成,loss:0.1750, Acc: 93.75%
# Epoch 9/50训练完成,loss:0.0008, Acc: 100.00%
# Epoch 9/50训练完成,loss:0.0096, Acc: 100.00%
# Epoch 9/50训练完成,loss:0.0648, Acc: 95.83%
# Epoch 9/50训练完成,loss:0.0698, Acc: 96.88%
# Epoch 9/50训练完成,loss:0.0827, Acc: 97.50%
# Epoch 9/50训练完成,loss:0.0866, Acc: 97.92%
# Epoch 9/50训练完成,loss:0.0939, Acc: 98.21%
# Epoch 9/50训练完成,loss:0.0945, Acc: 98.44%
# Epoch 9/50训练完成,loss:0.0974, Acc: 98.61%
# Epoch 9/50训练完成,loss:0.1012, Acc: 98.75%
# Epoch 10/50训练完成,loss:0.0087, Acc: 100.00%
# Epoch 10/50训练完成,loss:0.0201, Acc: 93.75%
# Epoch 10/50训练完成,loss:0.0250, Acc: 95.83%
# Epoch 10/50训练完成,loss:0.1140, Acc: 93.75%
# Epoch 10/50训练完成,loss:0.1143, Acc: 95.00%
# Epoch 10/50训练完成,loss:0.1198, Acc: 95.83%
# Epoch 10/50训练完成,loss:0.1285, Acc: 94.64%
# Epoch 10/50训练完成,loss:0.1306, Acc: 95.31%
# Epoch 10/50训练完成,loss:0.1309, Acc: 95.83%
# Epoch 10/50训练完成,loss:0.1309, Acc: 96.25%
# Epoch 11/50训练完成,loss:0.0246, Acc: 87.50%
# Epoch 11/50训练完成,loss:0.0679, Acc: 87.50%
# Epoch 11/50训练完成,loss:0.0684, Acc: 91.67%
# Epoch 11/50训练完成,loss:0.0687, Acc: 93.75%
# Epoch 11/50训练完成,loss:0.0898, Acc: 92.50%
# Epoch 11/50训练完成,loss:0.0965, Acc: 93.75%
# Epoch 11/50训练完成,loss:0.0979, Acc: 94.64%
# Epoch 11/50训练完成,loss:0.1263, Acc: 93.75%
# Epoch 35/50训练完成,loss:0.0004, Acc: 100.00%
# Epoch 35/50训练完成,loss:0.0023, Acc: 100.00%
# Epoch 35/50训练完成,loss:0.0077, Acc: 100.00%
# Epoch 35/50训练完成,loss:0.0127, Acc: 100.00%
# Epoch 35/50训练完成,loss:0.0129, Acc: 100.00%
# Epoch 35/50训练完成,loss:0.0243, Acc: 97.92%
# Epoch 35/50训练完成,loss:0.0338, Acc: 96.43%
# Epoch 35/50训练完成,loss:0.0442, Acc: 95.31%
# Epoch 35/50训练完成,loss:0.0443, Acc: 95.83%
# Epoch 35/50训练完成,loss:0.0443, Acc: 96.25%
# Epoch 36/50训练完成,loss:0.0003, Acc: 100.00%
# Epoch 36/50训练完成,loss:0.0041, Acc: 100.00%
# Epoch 36/50训练完成,loss:0.0056, Acc: 100.00%
# Epoch 36/50训练完成,loss:0.0213, Acc: 96.88%
# Epoch 36/50训练完成,loss:0.0226, Acc: 97.50%
# Epoch 36/50训练完成,loss:0.0922, Acc: 95.83%
# Epoch 36/50训练完成,loss:0.1635, Acc: 94.64%
# Epoch 36/50训练完成,loss:0.1637, Acc: 95.31%
# Epoch 36/50训练完成,loss:0.1643, Acc: 95.83%
# Epoch 36/50训练完成,loss:0.1661, Acc: 96.25%
# Epoch 37/50训练完成,loss:0.0001, Acc: 100.00%
# Epoch 37/50训练完成,loss:0.0008, Acc: 100.00%
# Epoch 37/50训练完成,loss:0.0642, Acc: 95.83%
# Epoch 37/50训练完成,loss:0.0644, Acc: 96.88%
# Epoch 37/50训练完成,loss:0.0645, Acc: 97.50%
# Epoch 37/50训练完成,loss:0.0708, Acc: 97.92%
# Epoch 37/50训练完成,loss:0.0725, Acc: 98.21%
# Epoch 37/50训练完成,loss:0.0727, Acc: 98.44%
# Epoch 37/50训练完成,loss:0.0753, Acc: 98.61%
# Epoch 37/50训练完成,loss:0.0761, Acc: 98.75%
# Epoch 38/50训练完成,loss:0.0007, Acc: 100.00%
# Epoch 38/50训练完成,loss:0.0041, Acc: 100.00%
# Epoch 38/50训练完成,loss:0.0053, Acc: 100.00%
# Epoch 38/50训练完成,loss:0.0058, Acc: 100.00%
# Epoch 38/50训练完成,loss:0.0761, Acc: 97.50%
# Epoch 38/50训练完成,loss:0.0820, Acc: 97.92%
# Epoch 38/50训练完成,loss:0.0824, Acc: 98.21%
# Epoch 38/50训练完成,loss:0.1119, Acc: 96.88%
# Epoch 38/50训练完成,loss:0.1126, Acc: 97.22%
# Epoch 38/50训练完成,loss:0.1129, Acc: 97.50%
# Epoch 39/50训练完成,loss:0.0165, Acc: 87.50%
# Epoch 39/50训练完成,loss:0.0328, Acc: 87.50%
# Epoch 39/50训练完成,loss:0.0360, Acc: 91.67%
# Epoch 39/50训练完成,loss:0.0407, Acc: 93.75%
# Epoch 39/50训练完成,loss:0.0453, Acc: 95.00%
# Epoch 39/50训练完成,loss:0.0467, Acc: 95.83%
# Epoch 39/50训练完成,loss:0.0477, Acc: 96.43%
# Epoch 39/50训练完成,loss:0.0496, Acc: 96.88%
# Epoch 39/50训练完成,loss:0.0768, Acc: 95.83%
# Epoch 39/50训练完成,loss:0.0770, Acc: 96.25%
# Epoch 40/50训练完成,loss:0.0013, Acc: 100.00%
# Epoch 40/50训练完成,loss:0.0014, Acc: 100.00%
# Epoch 40/50训练完成,loss:0.0040, Acc: 100.00%
# Epoch 40/50训练完成,loss:0.0197, Acc: 96.88%
# Epoch 40/50训练完成,loss:0.0198, Acc: 97.50%
# Epoch 40/50训练完成,loss:0.0205, Acc: 97.92%
# Epoch 40/50训练完成,loss:0.0206, Acc: 98.21%
# Epoch 40/50训练完成,loss:0.0237, Acc: 98.44%
# Epoch 40/50训练完成,loss:0.0612, Acc: 97.22%
# Epoch 40/50训练完成,loss:0.1076, Acc: 96.25%
# Epoch 41/50训练完成,loss:0.0001, Acc: 100.00%
# Epoch 41/50训练完成,loss:0.0392, Acc: 93.75%
# Epoch 41/50训练完成,loss:0.0394, Acc: 95.83%
# Epoch 41/50训练完成,loss:0.0402, Acc: 96.88%
# Epoch 41/50训练完成,loss:0.0504, Acc: 97.50%
# Epoch 41/50训练完成,loss:0.0516, Acc: 97.92%
# Epoch 41/50训练完成,loss:0.0530, Acc: 98.21%
# Epoch 41/50训练完成,loss:0.0584, Acc: 98.44%
# Epoch 41/50训练完成,loss:0.0676, Acc: 98.61%
# Epoch 41/50训练完成,loss:0.0693, Acc: 98.75%
# Epoch 42/50训练完成,loss:0.0023, Acc: 100.00%
# Epoch 42/50训练完成,loss:0.0043, Acc: 100.00%
# Epoch 42/50训练完成,loss:0.0061, Acc: 100.00%
# Epoch 42/50训练完成,loss:0.0085, Acc: 100.00%
# Epoch 42/50训练完成,loss:0.0091, Acc: 100.00%
# Epoch 42/50训练完成,loss:0.0130, Acc: 100.00%
# Epoch 42/50训练完成,loss:0.0142, Acc: 100.00%
# Epoch 42/50训练完成,loss:0.0197, Acc: 100.00%
# Epoch 42/50训练完成,loss:0.0205, Acc: 100.00%
# Epoch 42/50训练完成,loss:0.0210, Acc: 100.00%
# Epoch 43/50训练完成,loss:0.0017, Acc: 100.00%
# Epoch 43/50训练完成,loss:0.0018, Acc: 100.00%
# Epoch 43/50训练完成,loss:0.0019, Acc: 100.00%
# Epoch 43/50训练完成,loss:0.0021, Acc: 100.00%
# Epoch 43/50训练完成,loss:0.0022, Acc: 100.00%
# Epoch 43/50训练完成,loss:0.0035, Acc: 100.00%
# Epoch 43/50训练完成,loss:0.0035, Acc: 100.00%
# Epoch 43/50训练完成,loss:0.0046, Acc: 100.00%
# Epoch 43/50训练完成,loss:0.0060, Acc: 100.00%
# Epoch 43/50训练完成,loss:0.0060, Acc: 100.00%
# Epoch 44/50训练完成,loss:0.0002, Acc: 100.00%
# Epoch 44/50训练完成,loss:0.0034, Acc: 100.00%
# Epoch 44/50训练完成,loss:0.0035, Acc: 100.00%
# Epoch 44/50训练完成,loss:0.0035, Acc: 100.00%
# Epoch 44/50训练完成,loss:0.0049, Acc: 100.00%
# Epoch 44/50训练完成,loss:0.0049, Acc: 100.00%
# Epoch 44/50训练完成,loss:0.0050, Acc: 100.00%
# Epoch 44/50训练完成,loss:0.0055, Acc: 100.00%
# Epoch 44/50训练完成,loss:0.0071, Acc: 100.00%
# Epoch 44/50训练完成,loss:0.0071, Acc: 100.00%
# Epoch 45/50训练完成,loss:0.0000, Acc: 100.00%
# Epoch 45/50训练完成,loss:0.0000, Acc: 100.00%
# Epoch 45/50训练完成,loss:0.0000, Acc: 100.00%
# Epoch 45/50训练完成,loss:0.0001, Acc: 100.00%
# Epoch 45/50训练完成,loss:0.0489, Acc: 97.50%
# Epoch 45/50训练完成,loss:0.0489, Acc: 97.92%
# Epoch 45/50训练完成,loss:0.0489, Acc: 98.21%
# Epoch 45/50训练完成,loss:0.0489, Acc: 98.44%
# Epoch 45/50训练完成,loss:0.0500, Acc: 98.61%
# Epoch 45/50训练完成,loss:0.0501, Acc: 98.75%
# Epoch 46/50训练完成,loss:0.0001, Acc: 100.00%
# Epoch 46/50训练完成,loss:0.0001, Acc: 100.00%
# Epoch 46/50训练完成,loss:0.1354, Acc: 91.67%
# Epoch 46/50训练完成,loss:0.1391, Acc: 93.75%
# Epoch 46/50训练完成,loss:0.1392, Acc: 95.00%
# Epoch 46/50训练完成,loss:0.1423, Acc: 95.83%
# Epoch 46/50训练完成,loss:0.1773, Acc: 94.64%
# Epoch 46/50训练完成,loss:0.1774, Acc: 95.31%
# Epoch 46/50训练完成,loss:0.1786, Acc: 95.83%
# Epoch 46/50训练完成,loss:0.2074, Acc: 93.75%
# Epoch 47/50训练完成,loss:0.0388, Acc: 87.50%
# Epoch 47/50训练完成,loss:0.0419, Acc: 93.75%
# Epoch 47/50训练完成,loss:0.0561, Acc: 91.67%
# Epoch 47/50训练完成,loss:0.0563, Acc: 93.75%
# Epoch 47/50训练完成,loss:0.0568, Acc: 95.00%
# Epoch 47/50训练完成,loss:0.0733, Acc: 93.75%
# Epoch 47/50训练完成,loss:0.0759, Acc: 94.64%
# Epoch 47/50训练完成,loss:0.1239, Acc: 92.19%
# Epoch 47/50训练完成,loss:0.1369, Acc: 93.06%
# Epoch 47/50训练完成,loss:0.1427, Acc: 93.75%
# Epoch 48/50训练完成,loss:0.0071, Acc: 100.00%
# Epoch 48/50训练完成,loss:0.0100, Acc: 100.00%
# Epoch 48/50训练完成,loss:0.0246, Acc: 95.83%
# Epoch 48/50训练完成,loss:0.0325, Acc: 96.88%
# Epoch 48/50训练完成,loss:0.0330, Acc: 97.50%
# Epoch 48/50训练完成,loss:0.0341, Acc: 97.92%
# Epoch 48/50训练完成,loss:0.0858, Acc: 96.43%
# Epoch 48/50训练完成,loss:0.0904, Acc: 96.88%
# Epoch 48/50训练完成,loss:0.0932, Acc: 97.22%
# Epoch 48/50训练完成,loss:0.0938, Acc: 97.50%
# Epoch 49/50训练完成,loss:0.0006, Acc: 100.00%
# Epoch 49/50训练完成,loss:0.0052, Acc: 100.00%
# Epoch 49/50训练完成,loss:0.0077, Acc: 100.00%
# Epoch 49/50训练完成,loss:0.0498, Acc: 96.88%
# Epoch 49/50训练完成,loss:0.0531, Acc: 97.50%
# Epoch 49/50训练完成,loss:0.0535, Acc: 97.92%
# Epoch 49/50训练完成,loss:0.0538, Acc: 98.21%
# Epoch 49/50训练完成,loss:0.0552, Acc: 98.44%
# Epoch 49/50训练完成,loss:0.0556, Acc: 98.61%
# Epoch 49/50训练完成,loss:0.0570, Acc: 98.75%
# Epoch 50/50训练完成,loss:0.0047, Acc: 100.00%
# Epoch 50/50训练完成,loss:0.0052, Acc: 100.00%
# Epoch 50/50训练完成,loss:0.0054, Acc: 100.00%
# Epoch 50/50训练完成,loss:0.0057, Acc: 100.00%
# Epoch 50/50训练完成,loss:0.0062, Acc: 100.00%
# Epoch 50/50训练完成,loss:0.0200, Acc: 97.92%
# Epoch 50/50训练完成,loss:0.0208, Acc: 98.21%
# Epoch 50/50训练完成,loss:0.0212, Acc: 98.44%
# Epoch 50/50训练完成,loss:0.0226, Acc: 98.61%
# Epoch 50/50训练完成,loss:0.0231, Acc: 98.75%
# 测试精准度:91.67%

# %%
import tkinter as tk
from tkinter import filedialog, Label, Button
from PIL import Image, ImageTk
import numpy as np

model1 = WXZ().to(device)
model1.load_state_dict(torch.load('ikun_ball_model.pth', map_location=device))
model1.eval()
trans = test_transform
root = tk.Tk()
root.title('篮球和鸡AI识别')
root.geometry('800x600')
title_label = Label(root, text='篮球和鸡识别系统', font=('Arial', 20))
title_label.pack(pady=20)

image_frame = tk.Frame(root)
image_frame.pack(pady=20)
image_label = Label(image_frame)
image_label.pack()

result_frame = tk.Frame(root)
result_frame.pack(pady=20)
result_label = Label(result_frame, text='等待导入图片', font=('Arial', 20))
result_label.pack()


def import_image():
    file_path = filedialog.askopenfilename(title='选择图片', filetypes=[('图片文件', '*.jpg *.png')])
    if file_path:
        img = Image.open(file_path).convert('RGB')
        img = img.resize((300, 300), Image.LANCZOS)
        img_tk = ImageTk.PhotoImage(img)
        image_label.config(image=img_tk)
        image_label.image = img_tk

        img_tensor = trans(img).unsqueeze(0).to(device)
        with torch.no_grad():
            outputs = model1(img_tensor)
            probs = torch.softmax(outputs, dim=1)
            _, predicted = torch.max(outputs, 1)
            ball_prob = probs[0, 0].item()
            chicken_prob = probs[0, 1].item()
            if predicted == 0:
                result = f'篮球的概率是{ball_prob:.4f}'
            else:
                result = f'鸡的概率是{chicken_prob:.4f}'
            result_label.config(text=result)


import_button = Button(root, text='导入图片', command=import_image, font=('Arial', 12), bg='#4CAF50', fg='white',padx=20, pady=10)
import_button.pack()

Instruction_label = Label(root, text='篮球还是鸡？AI快速出答案！', font=('Arial', 10), fg='#666')
Instruction_label.pack(pady=10)
root.mainloop()
